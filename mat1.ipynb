# %%
import pandas as pd
url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv"
vacc_df = pd.read_csv(url)
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
vac_israel= vacc_df[vacc_df['location'].str.contains("Israel")]
vac_israel
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 11663   Israel      ISR  2020-12-19                60.0               60.0
# 11664   Israel      ISR  2020-12-20              7419.0             7419.0
# 11665   Israel      ISR  2020-12-21             32303.0            32303.0
# 11666   Israel      ISR  2020-12-22             76915.0            76915.0
# 11667   Israel      ISR  2020-12-23            139748.0           139748.0
# ...        ...      ...         ...                 ...                ...
# 11835   Israel      ISR  2021-06-09          10613376.0          5471766.0
# 11836   Israel      ISR  2021-06-10          10617667.0          5474941.0
# 11837   Israel      ISR  2021-06-11          10619306.0          5476180.0
# 11838   Israel      ISR  2021-06-12          10619532.0          5476317.0
# 11839   Israel      ISR  2021-06-13          10623711.0          5479333.0
#
# ...

# %%
vac_israel = vacc_df[vacc_df.location.str.contains("Israel")]
vac_israel.count()
# Out:
# location                               177
# iso_code                               177
# date                                   177
# total_vaccinations                     177
# people_vaccinated                      177
# people_fully_vaccinated                161
# daily_vaccinations_raw                 176
# daily_vaccinations                     176
# total_vaccinations_per_hundred         177
# people_vaccinated_per_hundred          177
# people_fully_vaccinated_per_hundred    161
# daily_vaccinations_per_million         176
# dtype: int64

# %%
type(vac_israel['date'])
# Out:
# pandas.core.series.Series

# %%
max_vac = vac_israel['daily_vaccinations'].max()
max_vac
vac_israel.loc[vac_israel.daily_vaccinations == max_vac, 'date'].values[0]
# Out:
# '2021-01-25'

# %%
vac_israel[['location','date','daily_vaccinations']].head(3)
# Out:
#       location        date  daily_vaccinations
# 11663   Israel  2020-12-19                 NaN
# 11664   Israel  2020-12-20              7359.0
# 11665   Israel  2020-12-21             16122.0

# %%
vac_israel[['daily_vaccinations']].mean()
# Out:
# daily_vaccinations    60686.193182
# dtype: float64

# %%
vac_israel['people_vaccinated_per_hundred'].isnull().sum()
# Out:
# 0

# %%
no_NaN_pvph= vac_israel.dropna(subset =["people_vaccinated_per_hundred"])
no_NaN_pvph
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 11663   Israel      ISR  2020-12-19                60.0               60.0
# 11664   Israel      ISR  2020-12-20              7419.0             7419.0
# 11665   Israel      ISR  2020-12-21             32303.0            32303.0
# 11666   Israel      ISR  2020-12-22             76915.0            76915.0
# 11667   Israel      ISR  2020-12-23            139748.0           139748.0
# ...        ...      ...         ...                 ...                ...
# 11835   Israel      ISR  2021-06-09          10613376.0          5471766.0
# 11836   Israel      ISR  2021-06-10          10617667.0          5474941.0
# 11837   Israel      ISR  2021-06-11          10619306.0          5476180.0
# 11838   Israel      ISR  2021-06-12          10619532.0          5476317.0
# 11839   Israel      ISR  2021-06-13          10623711.0          5479333.0
#
# ...

# %%
import statistics
statistics.harmonic_mean(vac_israel['people_vaccinated_per_hundred'])
# Out:
# 0

# %%
total_vaccinations_per_hundred
